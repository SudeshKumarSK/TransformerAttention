# %% [markdown]
# # Part 3 - Encoder-Decoder Attention Notebook
# ### Python notebook to get some hands-on to understand the concepts behind the Encoder-Decoder Attention.
# ----

# %% [markdown]
# ## Encoder-Only Transformer:
# The `Encoder-Only Transformer` uses Self-Attention to create `Context Aware Embeddings`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Decoder-Only Transformer:
# The `Decoder-Only Transformer` uses Masked Self-Attention to create `Generative Inputs` to generate long streams of new tokens.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Encoder-Decoder Attention aka Cross Attention!!

# %% [markdown]
# * The very first transformer which emerged before these super cool `Encoder-Only` and `Decoder-Only` Transformers had both Encoder and Decoder and these two were connected to each other so they can calculate something called `Encoder-Decoder Attention`
#
# * Encoder-Decoder attention uses the output from the `Encoder` to calculate the `Keys & Values` to perform the Encoder-Decoder Attention with the `Queries` calculated from the output of the `Masked Self Attention` generated by the `Decoder`.
#
# * Encoder-Decoder Attention is calculated just like `Self-Attention` where we attend the current token and all other tokens in the input sentence.
#
# * The first Transformer was based off of `Seq2Seq` model to perform tasks like Language Translation `(English to Spanish)`.
#
# * These `Encoder-Decoder Attention` mechanisms are still seen in `Multi-Model Models` where we use the Encoder to take in an Image and compute `Context Aware Embeddings` and passed on to the decoder to generate captions.

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)
